# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Initial Set-Up 🖥️

# %%
# !nvidia-smi
# Out:
# Thu May 18 10:54:44 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.1/715.1 kB 7.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# To check the model is detecting or not
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source='/content/drive/MyDrive/B.Tech ECE MMMUT/Personal Photos/1660543522327.jpg'
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 211MB/s]
# 2023-04-04 12:27:05.321970: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-04 12:27:06.280248: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.61 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l summary (fused): 268 layers, 43668288 parameters, 0 gradients, 165.2 GFLOPs
#
# image 1/1 /content/drive/MyDrive/B.Tech ECE MMMUT/Personal Photos/1660543522327.jpg: 480x640 13 persons, 8 sports balls, 1 tennis racket, 100.9ms
# Speed: 0.7ms preprocess, 100.9ms inference, 20.1ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# # 1. To detect Drones ✈️

# %%
# 1. To detect Drones
# !yolo task=detect mode=train model=yolov8n.pt data='/content/drive/MyDrive/Datasets/drone/data.yaml' epochs=60 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 112MB/s]
# Ultralytics YOLOv8.1.15 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # 2. To detect grassWeeds 🌿

# %%
# !yolo task=detect mode=train model=yolov8l.pt data='/content/drive/MyDrive/Datasets/grassWeeds/data.yaml' epochs=50 imgsz=640
# Out:
# ...
# 100% 83.7M/83.7M [00:01<00:00, 52.1MB/s]
# Ultralytics YOLOv8.0.69 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # 2.1 To detect Weeds 🌿

# %%
# !yolo task=detect mode=train model=yolov8n.pt data='/content/drive/MyDrive/Datasets/Weeds/data.yaml' epochs=50 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 278MB/s]
# Ultralytics YOLOv8.0.147 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # 3. To detect Bulls's Eye 🎯

# %%
# !yolo task=detect mode=train model=yolov8n.pt data='/content/drive/MyDrive/Datasets/Alvo finder.v1i.yolov8/data.yaml' epochs=50 imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.0.148 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.147 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## 4. Sign Language Detection

# %%
# !yolo task=detect mode=train model=yolov8l.pt data='/content/drive/MyDrive/Datasets/sign_recognition.v2i.yolov8/data.yaml' epochs=40 imgsz=640
# Out:
# Ultralytics YOLOv8.0.105 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
